# %%
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# טעינת הנתונים המוכנים שכבר עברו ניקוי במחברת 1
df = pd.read_csv('processed_data.csv')

# וודא שהסיווג קיים
print(df['group_label'].value_counts())
